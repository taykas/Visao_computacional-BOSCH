# %%
from tensorflow.keras import models, layers

# => input é colocar a camadas de cor que a imagem terá
# 
# => flaten achatar a imagem
# 
# => dense camada de neuronios conectados aos neuronios da camada anterior
# 
# => CONV2D

model = models.Sequential([
    
])

# %% [markdown]
# <h1>Visão Computacional</h1>
# Visão computacional é a área da computação que permite que máquinas interpretem imagens e vídeos. Para isso, usam-se principalmente redes neurais convolucionais (CNNs), que aprendem a reconhecer padrões visuais.
#
# Para um computador, uma imagem nada mais é do que uma matriz de números, representando valores de RGB (vermelho, verde e azul). O objetivo da visão computacional é ensinar a máquina a transformar esses números em algo com significado, como identificar objetos, rostos ou movimentos.
#
# 🔹 Como a rede neural interpreta a imagem?
#
# As redes neurais são compostas por milhões de neurônios artificiais. Cada neurônio faz uma série de cálculos simples, mas quando muitos deles trabalham juntos, conseguem detectar padrões cada vez mais complexos — bordas, formas, olhos, bocas, etc.
#
# Funciona como um filtro de decisão:
#
# Recebe várias informações (valores dos pixels ou resultados de neurônios anteriores)
#
# Avalia o quão importantes essas informações são
#
# Soma tudo
#
# Toma uma decisão
#
# 🔹 Fórmula de um neurônio
#
# A operação básica de um neurônio é:
#
# 𝑆 = ( 𝑤⋅𝑥 ) + 𝑏S = ( w⋅x ) + b
#
# Entrada (x): números vindos da imagem ou da camada anterior
# Peso (w): indica a importância de cada entrada
# Viés (b): ajusta a decisão final
# S: resultado dessa soma ponderada
# Esse valor S ainda não é a decisão do neurônio — falta um passo importantíssimo.
#
# 🔹 O papel da função de ativação
#
# Sem função de ativação, toda a rede seria apenas um modelo linear, incapaz de aprender relações complexas. A função de ativação é o que permite decisões não lineares, ou seja, que o modelo aprenda padrões reais do mundo.
#
# A função de ativação decide:
# Se a informação entra
# Se não entra
# Como ela entra
#
# Uma função muito comum é a sigmoid, que transforma o valor S em uma probabilidade entre 0 e 1.
#  Exemplo:
# A rede analisa a imagem
# A última camada gera:
# 𝑆=2.3
# S=2.3
#
# A função sigmoid converte:
#
# 𝑠𝑖𝑔𝑚𝑜𝑖𝑑(2.3)≈0.91
# sigmoid(2.3)≈0.91
#
# Isso pode ser interpretado como:
#
# "Há 91% de chance de a imagem conter um cachorro."
